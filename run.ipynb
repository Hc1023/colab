# %% [markdown]
# <a href="https://colab.research.google.com/github/Hc1023/colab/blob/master/run.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /gdrive/My Drive/Colab Notebooks/run
# Out:
# /gdrive/My Drive/Colab Notebooks/run

# %%
# !python3 'main.py'
# Out:
# Epoch:0, time cost:4.0361, train loss:0.5582
# Epoch:0, validation accuracy:0.7950, validation loss:0.5774
# Epoch:1, time cost:3.9948, train loss:0.4124
# Epoch:1, validation accuracy:0.7800, validation loss:0.4939
# Epoch:2, time cost:4.1030, train loss:0.3411
# Epoch:2, validation accuracy:0.7300, validation loss:0.5670
# Epoch:3, time cost:4.2191, train loss:0.3034
# Epoch:3, validation accuracy:0.8350, validation loss:0.4023
# Epoch:4, time cost:4.1136, train loss:0.2241
# Epoch:4, validation accuracy:0.8400, validation loss:0.4001
# Epoch:5, time cost:3.9116, train loss:0.1651
# Epoch:5, validation accuracy:0.8050, validation loss:0.5109
# Epoch:6, time cost:4.2485, train loss:0.1569
# Epoch:6, validation accuracy:0.7850, validation loss:0.5700
# Epoch:7, time cost:4.1541, train loss:0.1615
# Epoch:7, validation accuracy:0.7950, validation loss:0.5643
# Epoch:8, time cost:4.0508, train loss:0.1460
# Epoch:8, validation accuracy:0.7300, validation loss:0.6741
# ...

# %%
# !pwd
# Out:
# /gdrive/My Drive/Colab Notebooks/run

# %%
# !ls
# Out:
# data  LICENSE  model	  readme-table1.png
# lib   main.py  README.md  TrainDetail.xlsx

# %%
cd /gdrive/My Drive/Colab Notebooks/run/data/parameter/train_time:1
# Out:
# /gdrive/My Drive/Colab Notebooks/run/data/parameter/train_time:1

# %%
checkpoint = torch.load('checkpoint.pth.tar')

# %%
checkpoint
# Out:
# {'args': Namespace(adjust_lr=[60, 120, 160], base_path='data', batch_size=64, dataset='LIDC-IDRI', depth=28, dp=True, dr=0, epochs=60, image_size=[8, 8, 8], lr=0.01, lr_decay_ratio=0.2, momentum=0.9, nesterov=False, net_name='wideresnet', optimizer='SGD', train_time=1, wd=0.0005, width=2, workers=4, wul=0.02),
#  'epoch': 60,
#  'optimizer': {'param_groups': [{'dampening': 0,
#     'initial_lr': 0.01,
#     'lr': 0.01,
#     'momentum': 0.9,
#     'nesterov': False,
#     'params': [140296576043192,
#      140296576043264,
#      140296576044200,
#      140296576044272,
#      140296576044920,
#      140296450539592,
#      140296450539664,
#      140296450540240,
#      140296450540384,
#      140296450540456,
#      140296450541032,
#      140296450541176,
#      140296450541248,
#      140296450542040,
#      140296450542328,
#      140296450542400,
#      140296450543120,
#      140296450543408,
#      140296450543480,
#      140296450568912,
#      140296450569200,
# ...

# %%
cd /gdrive/My Drive/Colab Notebooks/run/data/runs/train_time:1
# Out:
# /gdrive/My Drive/Colab Notebooks/run/data/runs/train_time:1
